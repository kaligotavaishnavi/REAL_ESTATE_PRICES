# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.simplefilter('ignore')
#plt.style.use('dark_background')

# %%
data = pd.read_csv('Raw_Housing_Prices.csv')
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                None  ...             7
# ...

# %% [markdown]
# # EXPLORATION OF IMPORTED DATA

# %%
data.head(10)
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
# 5  7237550310         14 May 2017   1230000.0               4
# 6  1321400060        14 June 2017    257500.0               3
# 7  2008000270     15 January 2016    291850.0               3
# 8  2414600126       15 April 2016    229500.0               3
# 9  3793500160       15 March 2016    323000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# ...

# %%
data.tail(10)
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 21603  7852140040      14 August 2017    507250.0               3
# 21604  9834201367     15 January 2016    429000.0               3
# 21605  3448900210     14 October 2017    610685.0               4
# 21606  7936000429       15 March 2016   1010000.0               4
# 21607  2997800021    15 February 2016    475000.0               3
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 21603             2.50               2270.0              5536.0           2.0
# 21604             2.00               1490.0              1126.0           3.0
# ...

# %%
data.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
#to include strings
data.describe(include='all')
# Out:
#                   ID Date House was Sold    Sale Price  No of Bedrooms  \
# count   2.161300e+04               21613  2.160900e+04    21613.000000
# unique           NaN                  13           NaN             NaN
# top              NaN       15 April 2016           NaN             NaN
# freq             NaN                2231           NaN             NaN
# mean    4.580302e+09                 NaN  5.401984e+05        3.370842
# std     2.876566e+09                 NaN  3.673890e+05        0.930062
# min     1.000102e+06                 NaN  7.500000e+04        0.000000
# 25%     2.123049e+09                 NaN  3.219500e+05        3.000000
# 50%     3.904930e+09                 NaN  4.500000e+05        3.000000
# 75%     7.308900e+09                 NaN  6.450000e+05        4.000000
# max     9.900000e+09                 NaN  7.700000e+06       33.000000
#
#         No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        21613 non-null  object
# ...

# %%
data["Sale Price"].mean()
# Out:
# 540198.4357443658

# %%
data["Sale Price"].min()
# Out:
# 75000.0

# %%
data["Sale Price"].max()
# Out:
# 7700000.0

# %%
data["Sale Price"].std()
# Out:
# 367388.99446065375

# %%
data["Sale Price"].quantile(.25)
# Out:
# 321950.0

# %% [markdown]
# # UNIQUE FUNCTION

# %%
data["Condition of the House"].unique()
# Out:
# array(['Fair', 'Excellent', 'Good', 'Bad', 'Okay'], dtype=object)

# %%
np.std(data["Sale Price"])
# Out:
# 367380.4935294451

# %%
data["Sale Price"].std()-np.std(data["Sale Price"])
# Out:
# 8.500931208662223

# %% [markdown]
# # GRAPHS

# %%
plt.plot(data["Sale Price"])
plt.xlabel("Record Number")
plt.ylabel("Sale Price")
plt.title("My First Graph")
plt.show()

# %%
data.groupby("Condition of the House")['ID'].count()
# Out:
# Condition of the House
# Bad             30
# Excellent     1701
# Fair         14031
# Good          5679
# Okay           172
# Name: ID, dtype: int64

# %%
values=(30,1701,14031,5679,172)
labels=('bad','excellent','fair','good','okay')
plt.pie(values,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1996eba0400>,
# ...
#  [Text(1.099989541385049, 0.004796753434368107, 'bad'),
#   Text(1.0641591373844368, 0.27850553014475643, 'excellent'),
#   Text(-0.9085709380486652, 0.620079713047741, 'fair'),
#   Text(0.7046888223897579, -0.8446381850229934, 'good'),
#   Text(1.0996562341282203, -0.02749848619362501, 'okay')])

# %%
plt.bar(labels,values,color='Blue')
plt.bar(labels,values,color='blue',linewidth=5,linestyle='dashed')
plt.xlabel('Condition of the House')
plt.ylabel('Count of the House')
plt.title('MyFirst BGraph')
plt.show()

# %%
plt.scatter(x=data['Flat Area (in Sqft)'], y= data['Sale Price'], color='green')

# %%
plt.hist(x=data['Age of House (in Years)'],bins=10)
# Out:
# (array([3592., 2663., 2784., 2525., 3218., 2587., 1361., 1079.,  952.,
#          852.]),
#  array([  3. ,  14.5,  26. ,  37.5,  49. ,  60.5,  72. ,  83.5,  95. ,
#         106.5, 118. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x=data['Age of House (in Years)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1996f278d30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1996f288430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1996f2789d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1996f288af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1996f288e50>],
#  'means': []}

# %% [markdown]
# # OUTLIERS

# %%
plt.scatter(x=data['ID'],y=data['Sale Price'])

# %%
sns.boxplot(x=data['Sale Price'])
# Out:
# <AxesSubplot:xlabel='Sale Price'>

# %% [markdown]
# # TREATMENT OF OUTLIERS

# %%
q1=data['Sale Price'].quantile(0.25)
q3=data['Sale Price'].quantile(0.75)
iqr= q3-q1

# %%
upper_limit= q3+1.5*iqr
lower_limit= q1-1.5*iqr
upper_limit, lower_limit
# Out:
# (1129575.0, -162625.0)

# %%
def limit_imputer(value):
    if value>upper_limit:
        return upper_limit
    if value<lower_limit:
        return lower_limit
    else:
        return value

# %%
data['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.401984e+05
# std      3.673890e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: Sale Price, dtype: float64

# %%
data['Sale Price']=data['Sale Price'].apply(limit_imputer)

# %%
data['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.116186e+05
# std      2.500620e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      1.129575e+06
# Name: Sale Price, dtype: float64

# %% [markdown]
# # TREATMENT OF MISSING VALUES

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        21613 non-null  object
# ...

# %%
data.dropna(inplace=True,axis=0,subset=['Sale Price'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21605 non-null  float64
#  5   Flat Area (in Sqft)                        21600 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
plt.hist(data['Sale Price'],bins=10,color='violet')
plt.xlabel('interval')
plt.ylabel('Sale Price')
plt.title('histogram on Sale Price')
plt.show()

# %% [markdown]
# # INDEPENDENT NUMERICAL VARIABLES

# %%
len(data['Latitude'].unique())
# Out:
# 5034

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21605 non-null  float64
#  5   Flat Area (in Sqft)                        21600 non-null  float64
#  6   Lot Area (in Sqft)                         21600 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
numerical_columns= ['No of Bathrooms','Flat Area (in Sqft)','Lot Area (in Sqft)','Area of the House from Basement (in Sqft)','Latitude','Longitude','Living Area after Renovation (in Sqft)']

# %%
from sklearn.impute import SimpleImputer
imputer= SimpleImputer(missing_values= np.nan,strategy='median')
data[numerical_columns]=imputer.fit_transform(data[numerical_columns])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %%
imputer= SimpleImputer(missing_values= np.nan,strategy='most frequent')
data['Zipcode']=imputer.fit_transform(data['Zipcode'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-1a3e0922ae20> in <module>
#       1 imputer= SimpleImputer(missing_values= np.nan,strategy='most frequent')
# ----> 2 data['Zipcode']=imputer.fit_transform(data['Zipcode'])
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\impute\_base.py in fit(self, X, y)
#     286         self : SimpleImputer
#     287         """
# --> 288         X = self._validate_input(X, in_fit=True)
#     289
# ...

# %%
data['Zipcode'].shape
# Out:
# (21609,)

# %%
column=data['Zipcode'].values.reshape(-1,1)
column.shape
# Out:
# (21609, 1)

# %%
imputer= SimpleImputer(missing_values= np.nan,strategy='median')
data[numerical_columns]=imputer.fit_transform(data[numerical_columns])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Date House was Sold                        21609 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21609 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21609 non-null  float64
#  6   Lot Area (in Sqft)                         21609 non-null  float64
#  7   No of Floors                               21609 non-null  float64
#  8   Waterfront View                            21609 non-null  object
#  9   No of Times Visited                        21609 non-null  object
# ...

# %% [markdown]
# # VARIABLE TRANFORMATION
#
#
# UNIQUE VALUES TO NUMERIC VALUES

# %%
#change the datatype of zipcode
data['Zipcode']=data['Zipcode'].astype(object)
data.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                       object
# Latitude                                     float64
# ...

# %%
data['No of Times Visited'].unique()
# Out:
# array(['None', 'Thrice', 'Four', 'Twice', 'Once'], dtype=object)

# %%
#replacing unique values with numeric variables
mapping={'None':'0',
        'Once':'1',
        'Twice':'2',
        'Thrice':'3',
        'Four':'4'}
data['No of Times Visited']=data['No of Times Visited'].map(mapping)
data['No of Times Visited'].unique()
# Out:
# array(['0', '3', '4', '2', '1'], dtype=object)

# %%
data['Ever Renovate']=np.where(data['Renovated Year']==0,'No','Yes')

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ...  \
# 0              No                   0  ...
# 1              No                   0  ...
# ...

# %%
data['Purchase Year']= pd.DatetimeIndex(data['Date House was Sold']).year
data['Year Sincew Renovation']=np.where(data['Ever Renovate']=='Yes',abs(data['Purchase Year']-data['Renovated Year']),0)

# %%
data.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Age of House (in Years)  \
# 0              No                   0  ...                      63
# ...

# %%
data.drop(columns=['Purchase Year','Date House was Sold','Renovated Year'],inplace= True)

# %%
data.head()
# Out:
#            ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#   No of Times Visited Condition of the House  ...  \
# 0                   0                   Fair  ...
# 1                   0                   Fair  ...
# ...

# %% [markdown]
# # CORRELATION

# %%
data.corr()
# Out:
#                                                  ID  Sale Price  \
# ID                                         1.000000   -0.011529
# Sale Price                                -0.011529    1.000000
# No of Bedrooms                             0.001450    0.339407
# No of Bathrooms                            0.005233    0.535124
# Flat Area (in Sqft)                       -0.012379    0.695170
# Lot Area (in Sqft)                        -0.132153    0.101319
# No of Floors                               0.018653    0.298913
# Overall Grade                              0.013762    0.680914
# Area of the House from Basement (in Sqft) -0.010724    0.606527
# Basement Area (in Sqft)                   -0.005189    0.307513
# Age of House (in Years)                   -0.021524   -0.064306
# Latitude                                  -0.001983    0.402430
# Longitude                                  0.020720    0.045401
# Living Area after Renovation (in Sqft)    -0.002913    0.629944
# ...

# %%
data['Sale Price'].corr(data['Flat Area (in Sqft)'])
# Out:
# 0.6951704258420669

# %%
np.corrcoef(data['Sale Price'],data['Flat Area (in Sqft)'])
# Out:
# array([[1.        , 0.69517043],
#        [0.69517043, 1.        ]])

# %%
data.drop(columns=['ID']).corr()
# Out:
#                                            Sale Price  No of Bedrooms  \
# Sale Price                                   1.000000        0.339407
# No of Bedrooms                               0.339407        1.000000
# No of Bathrooms                              0.535124        0.515813
# Flat Area (in Sqft)                          0.695170        0.576628
# Lot Area (in Sqft)                           0.101319        0.031692
# No of Floors                                 0.298913        0.175536
# Overall Grade                                0.680914        0.349223
# Area of the House from Basement (in Sqft)    0.606527        0.477549
# Basement Area (in Sqft)                      0.307513        0.303294
# Age of House (in Years)                     -0.064306       -0.154113
# Latitude                                     0.402430       -0.008708
# Longitude                                    0.045401        0.129569
# ...

# %% [markdown]
# # CATEGORICAL VARIABLES

# %%
#convert categorical variables into numeric values
##### consider object type values #####

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21609 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21609 non-null  int64
#  1   Sale Price                                 21609 non-null  float64
#  2   No of Bedrooms                             21609 non-null  int64
#  3   No of Bathrooms                            21609 non-null  float64
#  4   Flat Area (in Sqft)                        21609 non-null  float64
#  5   Lot Area (in Sqft)                         21609 non-null  float64
#  6   No of Floors                               21609 non-null  float64
#  7   Waterfront View                            21609 non-null  object
#  8   No of Times Visited                        21609 non-null  object
#  9   Condition of the House                     21609 non-null  object
# ...

# %%
data['Condition of the House'].head(10)
# Out:
# 0         Fair
# 1         Fair
# 2         Fair
# 3    Excellent
# 4         Fair
# 5         Fair
# 6         Fair
# 7         Fair
# 8         Fair
# 9         Fair
# Name: Condition of the House, dtype: object

# %%
data['Condition of the House'].value_counts()
# Out:
# Fair         14028
# Good          5678
# Excellent     1701
# Okay           172
# Bad             30
# Name: Condition of the House, dtype: int64

# %%
data.groupby('Condition of the House')['Sale Price'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Condition of the House'>

# %%
data.groupby('Condition of the House')['Sale Price'].mean().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Condition of the House'>

# %% [markdown]
# # ANNOVA
#
# *//NO SPACES BETWEEN WORDS HERE WE HAVE TO REMOVE THE SPACES*

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
data= data.rename(columns={'Sale Price':'Sale_Price'})

# %%
data= data.rename(columns={'Condition of the House':'Condition_of_the_House'})

# %%
data= data.rename(columns={'Ever Renovate':'Ever_Renovate'})

# %%
data= data.rename(columns={'Waterfront View':'Waterfront_View'})

# %%
data.head()
# Out:
#            ID  Sale_Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront_View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#   No of Times Visited Condition_of_the_House  ...  \
# 0                   0                   Fair  ...
# 1                   0                   Fair  ...
# ...

# %%
mod=ols('Sale_Price ~ Condition_of_the_House',data=data).fit()
Anova_Table= sm.stats.anova_lm(mod,typ=2)
print(Anova_Table)
# Out:
#                               sum_sq       df         F        PR(>F)
# Condition_of_the_House  1.441831e+13      4.0  58.25563  5.447605e-49
# Residual                1.336752e+15  21604.0       NaN           NaN

# %%
mod=ols('Sale_Price ~ Waterfront_View',data=data).fit()
Anova_Table= sm.stats.anova_lm(mod,typ=2)
print(Anova_Table)
# Out:
#                        sum_sq       df           F         PR(>F)
# Waterfront_View  3.283737e+13      1.0  538.192683  1.275558e-117
# Residual         1.318333e+15  21607.0         NaN            NaN

# %%
mod=ols('Sale_Price ~Ever_Renovate ',data=data).fit()
Anova_Table= sm.stats.anova_lm(mod,typ=2)
print(Anova_Table)
# Out:
#                      sum_sq       df           F        PR(>F)
# Ever_Renovate  1.998463e+13      1.0  324.378469  5.419055e-72
# Residual       1.331185e+15  21607.0         NaN           NaN

# %%
mod=ols('Sale_Price ~ Zipcode ',data=data).fit()
Anova_Table= sm.stats.anova_lm(mod,typ=2)
print(Anova_Table)
# Out:
#                 sum_sq       df           F  PR(>F)
# Zipcode   6.859528e+14     69.0  321.882765     0.0
# Residual  6.652008e+14  21538.0         NaN     NaN

# %% [markdown]
# # CREATION OF DUMMY VARIABLES
#
# BY CREATING DUMMY VARIABLES WE CAN TRANSFER CATEGORICAL VALUES TO NUMERIC VALUES

# %%
data = pd.get_dummies(data,columns=['Condition_of_the_House'],drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-b6f17d95d8ac> in <module>
# ----> 1 data = pd.get_dummies(data,columns=['Condition_of_the_House'],drop_first=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     845             raise TypeError("Input must be a list-like for parameter `columns`")
#     846         else:
# --> 847             data_to_encode = data[columns]
#     848
#     849         # validate prefixes and separator to avoid silently dropping cols
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
# ...

# %%
.head()
# Out:
#            ID  Sale_Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront_View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#   No of Times Visited  Overall Grade  ...  Latitude  Longitude  \
# 0                   0              7  ...   47.5112   -122.257
# ...

# %% [markdown]
# # BINNING
#
# WE USE BINNING IF NUMBER OF CATEGORICAL VAR ARE MORE WE BIN THEM

# %%
Zip_table= data.groupby('Zipcode').agg({'Sale_Price':'mean'}).sort_values('Sale_Price',ascending=True)

# %%
Zip_table.head()
# Out:
#             Sale_Price
# Zipcode
# 98002.0  234284.035176
# 98168.0  240328.371747
# 98032.0  251296.240000
# 98001.0  280804.690608
# 98148.0  284908.596491

# %%
Zip_table['Zipcode_Group']=pd.cut(Zip_table['Sale_Price'],bins=10,
                                 labels=['Zipcode_Group=0',
                                        'Zipcode_Group=1',
                                        'Zipcode_Group=2',
                                        'Zipcode_Group=3',
                                        'Zipcode_Group=4',
                                        'Zipcode_Group=5',
                                        'Zipcode_Group=6',
                                        'Zipcode_Group=7',
                                        'Zipcode_Group=8',
                                        'Zipcode_Group=9'],
                                 include_lowest = True)

# %%
Zip_table= Zip_table.drop(columns='Sale_Price')

# %%
data.head()
# Out:
#            ID  Sale_Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront_View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#   No of Times Visited  Overall Grade  ...  Latitude  Longitude  \
# 0                   0              7  ...   47.5112   -122.257
# ...

# %%
data= pd.merge(data,Zip_table,left_on='Zipcode',how='left',right_index=True)

# %%
data=data.drop(columns='Zipcode')

# %%
data.head()
# Out:
#            ID  Sale_Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront_View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#   No of Times Visited  Overall Grade  ...  Longitude  \
# 0                   0              7  ...   -122.257
# 1                   0              7  ...   -122.319
# ...

# %%
data= pd.get_dummies(data, columns=['Zipcode_Group'],drop_first= True)

# %%
data.head()
# Out:
#            ID  Sale_Price  No of Bedrooms  No of Bathrooms  \
# 0  7129300520    221900.0               3             1.00
# 1  6414100192    538000.0               3             2.25
# 2  5631500400    180000.0               2             1.00
# 3  2487200875    604000.0               4             3.00
# 4  1954400510    510000.0               3             2.00
#
#    Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors Waterfront_View  \
# 0               1180.0              5650.0           1.0              No
# 1               2570.0              7242.0           2.0              No
# 2                770.0             10000.0           1.0              No
# 3               1960.0              5000.0           1.0              No
# 4               1680.0              8080.0           1.0              No
#
#   No of Times Visited  Overall Grade  ...  Condition_of_the_House_Okay  \
# 0                   0              7  ...                            0
# ...

# %% [markdown]
# # TRAIN AND TEST DATA
#
# Y= DEPENDENT VARIABLE
# X= INDEPENDENT VARIABLE

# %%
Y=data.iloc[:,0]
X=data.iloc[:,1:31]

# %%
X.head()
# Out:
#    Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0    221900.0               3             1.00               1180.0
# 1    538000.0               3             2.25               2570.0
# 2    180000.0               2             1.00                770.0
# 3    604000.0               4             3.00               1960.0
# 4    510000.0               3             2.00               1680.0
#
#    Lot Area (in Sqft)  No of Floors Waterfront_View No of Times Visited  \
# 0              5650.0           1.0              No                   0
# 1              7242.0           2.0              No                   0
# 2             10000.0           1.0              No                   0
# 3              5000.0           1.0              No                   0
# 4              8080.0           1.0              No                   0
#
#    Overall Grade  Area of the House from Basement (in Sqft)  ...  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
X_train.shape
# Out:
# (15126, 30)

# %%
X_test.shape
# Out:
# (6483, 30)

# %%
Y_train.shape
# Out:
# (15126,)

# %%
Y_test.shape
# Out:
# (6483,)

# %% [markdown]
# # FEATURE SCALING

# %%
X.describe()
# Out:
#          Sale_Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# count  2.160900e+04    21609.000000     21609.000000         21609.000000
# mean   5.116186e+05        3.370771         2.114709          2079.872553
# std    2.500620e+05        0.929916         0.770097           918.347816
# min    7.500000e+04        0.000000         0.000000           290.000000
# 25%    3.219500e+05        3.000000         1.750000          1430.000000
# 50%    4.500000e+05        3.000000         2.250000          1910.000000
# 75%    6.450000e+05        4.000000         2.500000          2550.000000
# max    1.129575e+06       33.000000         8.000000         13540.000000
#
#        Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count        2.160900e+04  21609.000000   21609.000000
# mean         1.510641e+04      1.494215       7.623490
# std          4.142353e+04      0.539909       1.105519
# min          5.200000e+02      1.000000       1.000000
# ...

# %%
from sklearn import preprocessing 
Scale=preprocessing.StandardScaler()
